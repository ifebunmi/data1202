# %%
import mysql.connector as sql
import pandas as pd

# %%
mycon=sql.connect(host='localhost',user='omar',password='foo',db='ap')
mycon

# %% [markdown]
# Any one can guide me how to embed the user and password within a code

# %% [markdown]
# <details><summary>Click here for a solution</summary>
#
# ```python
#     #The correct answer is:
#    df2=pd.read_csv('C:/Users/omar/Desktop/Duraham/Courses/data1202/mysql.txt', sep=',')
#
#    mydb1=sql.connect(host='localhost',user=df2.iat[0,0],password=df2.iat[0,1], db='ap')
#
# ```
#
# </details>

# %%
df=pd.read_sql_query('SELECT * From vendors',mycon)
df
# Out:
#      vendor_id                      vendor_name  \
# 0            1                US Postal Service
# 1            2    National Information Data Ctr
# 2            3           Register of Copyrights
# 3            4                          Jobtrak
# 4            5              Newbrige Book Clubs
# 5            6   California Chamber Of Commerce
# 6            7  Towne Advertiser's Mailing Svcs
# 7            8                   BFI Industries
# 8            9           Pacific Gas & Electric
# 9           10      Robbins Mobile Lock And Key
# 10          11         Bill Marvin Electric Inc
# 11          12                   City Of Fresno
# 12          13        Golden Eagle Insurance Co
# 13          14                     Expedata Inc
# 14          15                        ASC Signs
# 15          16         Internal Revenue Service
# 16          17   Blanchard & Johnson Associates
# 17          18    Fresno Photoengraving Company
# ...

# %%
x=pd.read_sql_query("show databases",mycon)
print(x)
# Out:
#              Database
# 0                  ap
# 1           data_1202
# 2                  ex
# 3  information_schema
# 4               mysql
# 5                  om
# 6  performance_schema
# 7              sakila
# 8                 sys
# 9               world
